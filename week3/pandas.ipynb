# %% [markdown]
# <a href="https://colab.research.google.com/github/tjdudgml3/ms_aischool/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas
# Series 1dim, dataFrame 2dim
from pandas import Series

# %%
fruit = Series([2500,3800,1200,6000],index = ['apple','banana', 'peer','cherry'])

# %%
fruit
# Out:
# apple     2500
# banana    3800
# peer      1200
# cherry    6000
# dtype: int64

# %%
print(fruit.values)
print(fruit.index)
# Out:
# [2500 3800 1200 6000]
# Index(['apple', 'banana', 'peer', 'cherry'], dtype='object')

# %%
#dict 표현
fruitData ={'apple' : [1,2], 'banana': 3800, 'peer': 1200, 'cherry' : 6000}
fruit = Series(fruitData)

# %%
fruit
# Out:
# apple     [1, 2]
# banana      3800
# peer        1200
# cherry      6000
# dtype: object

# %%
#Series 객체의 이름과 컬럼명의 설정
fruit.name = 'fruitPrice'
fruit.index.name = 'fruitName'

# %%
fruit
# Out:
# fruitName
# apple     [1, 2]
# banana      3800
# peer        1200
# cherry      6000
# Name: fruitPrice, dtype: object

# %%
#DataFrame
fruitData = {'fruitName':['apple','banana','peer','cherry'],
             'fruitPrice': [2500,3800,1200,6000],
             'num': [10,5,3,8]}

# %%
from pandas import DataFrame
fruitFrame = DataFrame(fruitData)

# %%
fruitFrame
# Out:
#   fruitName  fruitPrice  num
# 0     apple        2500   10
# 1    banana        3800    5
# 2      peer        1200    3
# 3    cherry        6000    8

# %%
#컬럼순서 지정하기

fruitFrame = DataFrame(fruitData,columns =['fruitPrice','num','fruitName'])

# %%
fruitFrame
# Out:
#    fruitPrice  num fruitName
# 0        2500   10     apple
# 1        3800    5    banana
# 2        1200    3      peer
# 3        6000    8    cherry

# %%
#특정항목 추출하기
fruitFrame['fruitName']
# Out:
# 0     apple
# 1    banana
# 2      peer
# 3    cherry
# Name: fruitName, dtype: object

# %%
#특정항목추출하기
fruitFrame['Year'] = 2022

# %%
fruitFrame
# Out:
#    fruitPrice  num fruitName  Year
# 0        2500   10     apple  2022
# 1        3800    5    banana  2022
# 2        1200    3      peer  2022
# 3        6000    8    cherry  2022

# %%
#series 객체의 추가
variable = Series([4,2,1],index = [0,2,3])
fruitFrame['stock'] = variable

# %%
fruitFrame
# Out:
#    fruitPrice  num fruitName  Year  stock
# 0        2500   10     apple  2022    4.0
# 1        3800    5    banana  2022    NaN
# 2        1200    3      peer  2022    2.0
# 3        6000    8    cherry  2022    1.0

# %%
#자료구조 다루기
#데이터구조의 항목 삭제
new_fruit = fruit.drop('banana')
new_fruit
# Out:
# fruitName
# apple     [1, 2]
# peer        1200
# cherry      6000
# Name: fruitPrice, dtype: object

# %%
fruitData
# Out:
# {'fruitName': ['apple', 'banana', 'peer', 'cherry'],
#  'fruitPrice': [2500, 3800, 1200, 6000],
#  'num': [10, 5, 3, 8]}

# %%
fruitName = fruitData['fruitName']
fruitName
# Out:
# ['apple', 'banana', 'peer', 'cherry']

# %%
fruitFrame = DataFrame(fruitData,index = fruitName,columns = ['fruitPrice','num'])

# %%
fruitFrame.drop(['apple','cherry'])
# Out:
#         fruitPrice  num
# banana        3800    5
# peer          1200    3

# %%
fruitFrame.drop(columns = fruitFrame.columns[0]) # fruitFrame.drop('fruitPrice',axis = 1)
# Out:
#         num
# apple    10
# banana    5
# peer      3
# cherry    8

# %%
fruitFrame.drop(fruitFrame.index[0]) # fruitFrame.drop('apple')
# Out:
#         fruitPrice  num
# banana        3800    5
# peer          1200    3
# cherry        6000    8

# %%
fruitFrame[:'peer']
# Out:
#         fruitPrice  num
# apple         2500   10
# banana        3800    5
# peer          1200    3

# %%
fruit1 = Series([5,9,10,3],index = ['apple','banana','cherry','peer'])

# %%
fruit2 = Series([3,2,9,5,10],index = ['apple','orange','banana','cherry','mango'])

# %%
newFruit = fruit1 + fruit2
newFruit
# Out:
# apple      8.0
# banana    18.0
# cherry    15.0
# mango      NaN
# orange     NaN
# peer       NaN
# dtype: float64

# %%
#DataFrame 객체의 기본연산
fruitData1 = {'Ohio':[4,8,3,5],
              'Texas':[0,1,2,3]}
fruitData2 = {'Ohio' : [3,0,2,1,7],
              'colorado' : [5,4,3,6,0],
              'asd' : [2,3,4,2,3]}
fruitFrame1 = DataFrame(fruitData1,columns = ['Ohio','Texas'],index = ['apple','bananana','cherry','peer'])
fruitFrame2 = DataFrame(fruitData2,columns = ['Ohio','colorado','asd'],index = ['apple','orange','bananana','cherry','mango'])

# %%
print(fruitFrame1)
print(fruitFrame2)
# Out:
#           Ohio  Texas
# apple        4      0
# bananana     8      1
# cherry       3      2
# peer         5      3
#           Ohio  colorado  asd
# apple        3         5    2
# orange       0         4    3
# bananana     2         3    4
# cherry       1         6    2
# mango        7         0    3

# %%
newFruitFrame = fruitFrame1 + fruitFrame2
newFruitFrame
# Out:
#           Ohio  Texas  asd  colorado
# apple      7.0    NaN  NaN       NaN
# bananana  10.0    NaN  NaN       NaN
# cherry     4.0    NaN  NaN       NaN
# mango      NaN    NaN  NaN       NaN
# orange     NaN    NaN  NaN       NaN
# peer       NaN    NaN  NaN       NaN

# %%
fruitFrame1.merge(fruitFrame2)
# Out:
#    Ohio  Texas  colorado  asd
# 0     3      2         5    2

# %%
fruit.apple = 700

# %%
fruit
# Out:
# fruitName
# apple      700
# banana    3800
# peer      1200
# cherry    6000
# Name: fruitPrice, dtype: object

# %%
fruit.sort_values()
# Out:
# fruitName
# apple      700
# peer      1200
# banana    3800
# cherry    6000
# Name: fruitPrice, dtype: object

# %%
fruit.sort_values(ascending = False)
# Out:
# fruitName
# cherry    6000
# banana    3800
# peer      1200
# apple      700
# Name: fruitPrice, dtype: object

# %%
fruitName = fruitData['fruitName']
fruitData
# Out:
# {'fruitName': ['apple', 'banana', 'peer', 'cherry'],
#  'fruitPrice': [2500, 3800, 1200, 6000],
#  'num': [10, 5, 3, 8]}

# %%
fruitFrame = DataFrame(fruitData,index = fruitName, columns = ['num','fruitPrice'])
fruitFrame
# Out:
#         num  fruitPrice
# apple    10        2500
# banana    5        3800
# peer      3        1200
# cherry    8        6000

# %%
fruitFrame.sort_index(ascending = False)
# Out:
#         num  fruitPrice
# peer      3        1200
# cherry    8        6000
# banana    5        3800
# apple    10        2500

# %%
fruitFrame.sort_index(axis = 1)
# Out:
#         fruitPrice  num
# apple         2500   10
# banana        3800    5
# peer          1200    3
# cherry        6000    8

# %%
fruitFrame.sort_values(by = ['fruitPrice', 'num'])
# Out:
#         num  fruitPrice
# peer      3        1200
# apple    10        2500
# banana    5        3800
# cherry    8        6000

# %%
fruitFrame.count(1)
# Out:
# apple     2
# banana    2
# peer      2
# cherry    2
# dtype: int64

# %%
#pandas 이용한 기초분석
import pandas as pd

# %%
german = pd.read_csv('http://freakonometrics.free.fr/german_credit.csv',sep = ',')

# %%
(german)
# Out:
#      Creditability  Account Balance  Duration of Credit (month)  \
# 0                1                1                          18
# 1                1                1                           9
# 2                1                2                          12
# 3                1                1                          12
# 4                1                1                          12
# ..             ...              ...                         ...
# 995              0                1                          24
# 996              0                1                          24
# 997              0                4                          21
# 998              0                2                          12
# 999              0                1                          30
#
#      Payment Status of Previous Credit  Purpose  Credit Amount  \
# 0                                    4        2           1049
# 1                                    4        0           2799
# ...

# %%
german.columns.values
# Out:
# array(['Creditability', 'Account Balance', 'Duration of Credit (month)',
#        'Payment Status of Previous Credit', 'Purpose', 'Credit Amount',
#        'Value Savings/Stocks', 'Length of current employment',
#        'Instalment per cent', 'Sex & Marital Status', 'Guarantors',
#        'Duration in Current address', 'Most valuable available asset',
#        'Age (years)', 'Concurrent Credits', 'Type of apartment',
#        'No of Credits at this Bank', 'Occupation', 'No of dependents',
#        'Telephone', 'Foreign Worker'], dtype=object)

# %%
german_sample= german[['Creditability','Duration of Credit (month)','Purpose','Credit Amount']]

# %%
# german_sample = german['Creditability']
german_sample[5:][10:]
# Out:
#      Creditability  Duration of Credit (month)  Purpose  Credit Amount
# 15               1                           6        3           2647
# 16               1                          11        0           3939
# 17               1                          18        3           3213
# 18               1                          36        3           2337
# 19               1                          11        0           7228
# ..             ...                         ...      ...            ...
# 995              0                          24        3           1987
# 996              0                          24        0           2303
# 997              0                          21        0          12680
# 998              0                          12        3           6468
# 999              0                          30        2           6350
#
# [985 rows x 4 columns]

# %%
german_sample.head()
# Out:
#    Creditability  Duration of Credit (month)  Purpose  Credit Amount
# 0              1                          18        2           1049
# 1              1                           9        0           2799
# 2              1                          12        9            841
# 3              1                          12        0           2122
# 4              1                          12        0           2171

# %%
german_sample.corr()
# Out:
#                             Creditability  Duration of Credit (month)  \
# Creditability                    1.000000                   -0.214927
# Duration of Credit (month)      -0.214927                    1.000000
# Purpose                         -0.017979                    0.147492
# Credit Amount                   -0.154740                    0.624988
#
#                              Purpose  Credit Amount
# Creditability              -0.017979      -0.154740
# Duration of Credit (month)  0.147492       0.624988
# Purpose                     1.000000       0.068480
# Credit Amount               0.068480       1.000000

# %%
#groupBy 를 이용한 계산및 통계
german_sample = german[['Credit Amount','Type of apartment']]

# %%
german_sample
# Out:
#      Credit Amount  Type of apartment
# 0             1049                  1
# 1             2799                  1
# 2              841                  1
# 3             2122                  1
# 4             2171                  2
# ..             ...                ...
# 995           1987                  1
# 996           2303                  2
# 997          12680                  3
# 998           6468                  2
# 999           6350                  2
#
# [1000 rows x 2 columns]

# %%
german_grouped = german_sample['Credit Amount'].groupby(german_sample['Type of apartment'])

# %%
german_grouped.mean()
# Out:
# Type of apartment
# 1    3122.553073
# 2    3067.257703
# 3    4881.205607
# Name: Credit Amount, dtype: float64

# %%
german_grouped.sample()
# Out:
# 801    1285
# 739    6148
# 882    7763
# Name: Credit Amount, dtype: int64

# %%
german_sample = german[['Type of apartment','Sex & Marital Status','Credit Amount']]

# %%
for type,group in german_sample.groupby('Type of apartment'):
  print(type)
  print(group)
# Out:
# 1
#      Type of apartment  Sex & Marital Status  Credit Amount
# 0                    1                     2           1049
# 1                    1                     3           2799
# 2                    1                     2            841
# 3                    1                     3           2122
# 5                    1                     3           2241
# ..                 ...                   ...            ...
# 983                  1                     2           1882
# 989                  1                     2           2718
# 993                  1                     2           3966
# 994                  1                     3           6199
# 995                  1                     3           1987
#
# [179 rows x 3 columns]
# 2
#      Type of apartment  Sex & Marital Status  Credit Amount
# 4                    2                     3           2171
# 6                    2                     3           3398
# ...

# %%
for (type,sex),group in german_sample.groupby(['Type of apartment','Sex & Marital Status']):
  print(type,sex)
  print(group.head())
# Out:
# 1 1
#      Type of apartment  Sex & Marital Status  Credit Amount
# 369                  1                     1           3021
# 777                  1                     1           3384
# 797                  1                     1           2319
# 857                  1                     1           2302
# 932                  1                     1           1223
# 1 2
#     Type of apartment  Sex & Marital Status  Credit Amount
# 0                   1                     2           1049
# 2                   1                     2            841
# 9                   1                     2           3758
# 26                  1                     2            652
# 39                  1                     2           3868
# 1 3
#     Type of apartment  Sex & Marital Status  Credit Amount
# 1                   1                     3           2799
# 3                   1                     3           2122
# 5                   1                     3           2241
# ...

# %%
import seaborn as sns
planets = sns.load_dataset('planets')

# %%
planets.shape
# Out:
# (1035, 6)

# %%
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
planets.dropna()
# Out:
#               method  number  orbital_period    mass  distance  year
# 0    Radial Velocity       1       269.30000   7.100     77.40  2006
# 1    Radial Velocity       1       874.77400   2.210     56.95  2008
# 2    Radial Velocity       1       763.00000   2.600     19.84  2011
# 3    Radial Velocity       1       326.03000  19.400    110.62  2007
# 4    Radial Velocity       1       516.22000  10.500    119.47  2009
# ..               ...     ...             ...     ...       ...   ...
# 640  Radial Velocity       1       111.70000   2.100     14.90  2009
# 641  Radial Velocity       1         5.05050   1.068     44.46  2013
# 642  Radial Velocity       1       311.28800   1.940     17.24  1999
# 649          Transit       1         2.70339   1.470    178.00  2013
# 784  Radial Velocity       3       580.00000   0.947    135.00  2012
#
# [498 rows x 6 columns]

# %%
births = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-CDCbirths/master/births.csv')

# %%
births.head()
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
births['decade'] = births['year'] // 10 * 10

# %%
births.pivot_table('births',index = 'decade',columns = 'gender',aggfunc = 'sum')
# Out:
# gender         F         M
# decade
# 1960     1753634   1846572
# 1970    16263075  17121550
# 1980    18310351  19243452
# 1990    19479454  20420553
# 2000    18229309  19106428

# %%
import matplotlib.pyplot as plt

# %%
births.pivot_table('births', index = 'decade',columns = 'gender',aggfunc = 'sum').plot()
