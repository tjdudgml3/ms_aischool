# %% [markdown]
# <a href="https://colab.research.google.com/github/tjdudgml3/ms_aischool/blob/main/webcrawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import bs4
import requests

# %%
url = 'https://search.shopping.naver.com/search/category/100005307'
result = requests.get(url).text

# %%
result
# Out:
# '<!DOCTYPE html><html lang="ko"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title>네이버 쇼핑</title><link rel="shortcut icon" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221019-193728/img/favicon.ico"/><meta property="og:title" content="네이버 쇼핑"/><meta property="og:image" content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png"/><meta property="og:description" content="네이버쇼핑 카테고리 검색 결과입니다"/><meta name="next-head-count" content="7"/><link rel="preconnect" href="https://static.nid.naver.com"/><link rel="preconnect" href="https://lcs.naver.com"/><link rel="preconnect" href="http://shopping.phinf.naver.net"/><link rel="preconnect" href="https://ssl.pstatic.net"/><link rel="preconnect" href="https://shopping-phinf.pstatic.net"/><link rel="preconnect" href="https://volts.shopping.naver.com"/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221019-193728/_next/static/css/49c7f5393b78dfc7.c
# ...

# %%
parser = bs4.BeautifulSoup(result,'html.parser')

# %%
items = parser.find_all('a',{'class' : "basicList_link__JLQJf" })

# %%
for item in items:
  print(item)
# Out:
# <a class="basicList_link__JLQJf" data-nclick="N=a:lst*B.title,i:26529080523,r:1" data-testid="SEARCH_PRODUCT_AD" href="https://adcr.naver.com/adcr?x=CtUekleWKxCj8T8yyKbSmf///w==..." rel="noopener" target="_blank" title="삼성전자 노트북 플러스2 NT550XDA-K14A">삼성전자 노트북 플러스2 NT550XDA-K14A</a>
# <a class="basicList_link__JLQJf" data-nclick="N=a:lst*B.title,i:34956428618,r:9" data-testid="SEARCH_PRODUCT_AD" href="https://adcr.naver.com/adcr?x=iAzfqq1pzaDu9FwBRrkDr////w==..." rel="noopener" target="_blank" title="LG전자 LG그램 16ZD90Q-SX76K">LG전자 LG그램 16ZD90Q-SX76K</a>
# <a class="basicList_link__JLQJf" data-nclick="N=a:lst*B.title,i:26962413523,r:2" data-testid="SEARCH_PRODUCT_AD" href="https://adcr.naver.com/adcr?x=5l1AjQMIbcDmvrotOOE36////w==..." rel="noopener" target="_blank" title="삼성전자 갤럭시북 프로360 NT950QDY-A51A">삼성전자 갤럭시북 프로360 NT950QDY-A51A</a>
# ...

# %%
# Out:
# '삼성전자 노트북 플러스2 NT550XDA-K14A'
