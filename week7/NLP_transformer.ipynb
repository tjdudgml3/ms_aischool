# %% [markdown]
# <a href="https://colab.research.google.com/github/tjdudgml3/ms_aischool/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 182 kB 42.6 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 37.1 MB/s
# ...

# %%
import transformers

# %%
from transformers import ElectraTokenizer


tokenizer = ElectraTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")
tokenizer.tokenize('안녕하세요, 제 이름은 홍길동입니다.')
# Out:
# Downloading:   0%|          | 0.00/263k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/61.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/467 [00:00<?, ?B/s]
# ['안녕', '##하', '##세요', ',', '제', '이름', '##은', '홍길동', '##입니다', '.']

# %%
tokenizer('안녕하세요')
tokenizer.tokenize('오늘 날씨가 참 좋네요')
# Out:
# ['오늘', '날씨', '##가', '참', '좋', '##네', '##요']

# %% [markdown]
# 토크나이저 훈련
#
# 1.  어떤 기법을 사용할지
# 2. vocab_size 결정 -> 작으면 메모리적으로 이득, 크면 의미적으로 잘 표현할수있다
# 3. corpus 통계적으로 분석(책을 1000권 넣기)
#
# tokenizer에 vocab을 수동으로 직접 추가.
#
# vocab 300-350 [UNK1], [UNK2], [UNK3] 더미로 놔뒀다가  필요할때 매핑해준다.

# %%
tokenizer.convert_ids_to_tokens(123)
# Out:
# 'г'

# %%
tokenizer.convert_tokens_to_ids('안녕')
# Out:
# 11655

# %%
tokenizer
# Out:
# PreTrainedTokenizer(name_or_path='bert-base-uncased', vocab_size=30522, model_max_len=512, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
tokenizer.tokenize('안녕하세요')#이모델이 영어모델이기때문에 이상하게나옴
# Out:
# ['ᄋ',
#  '##ᅡ',
#  '##ᆫ',
#  '##ᄂ',
#  '##ᅧ',
#  '##ᆼ',
#  '##ᄒ',
#  '##ᅡ',
#  '##ᄉ',
#  '##ᅦ',
#  '##ᄋ',
#  '##ᅭ']

# %%
tokenizer.tokenize('hello world' )
# Out:
# ['hello', 'world']

# %%
tokenizer.vocab_size
# Out:
# 30522

# %%
multi_tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
# Out:
# Downloading:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]

# %%
multi_tokenizer.tokenize('안녕하세요')
# Out:
# ['안', '##녕', '##하', '##세', '##요']

# %%
multi_tokenizer.tokenize('')
# Out:
# ['윈', '##도', '##우', '.']

# %%
electra_tokenizer = ElectraTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")

# %%
electra_tokenizer.tokenize('한국어 잘 분리하는 모델이네.')
# Out:
# ['한국어', '잘', '분리', '##하', '##는', '모델', '##이', '##네', '.']

# %%
from transformers import RobertaTokenizer

roberta_tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
# Out:
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]

# %%
roberta_tokenizer.vocab_size
# Out:
# 50265

# %%
roberta_tokenizer.convert_ids_to_tokens([8,22,33,3])
# Out:
# ['Ġand', 'Ġ"', 'Ġhave', '<unk>']

# %%
roberta_tokenizer.tokenize('hello my friends nice to meet ya')
# Out:
# ['hello', 'Ġmy', 'Ġfriends', 'Ġnice', 'Ġto', 'Ġmeet', 'Ġya']

# %%
roberta_tokenizer.convert_tokens_to_ids('hello my friends')
# Out:
# 3

# %%
roberta_tokenizer.convert_tokens_to_ids('hello')
# Out:
# 42891

# %%
# 3가지 언어모델

# 1. decoder-only 모델 (GPT1, GPT2, GPT3 - few shot learning 사용)
# 단점 = 모델이 너무 크다. -> pretraining, fine tuning 필요

# 2. encoder-only 모델 (BERT, RoBERTa, ELectra= pre training >> fine-tuning 메커니즘)
# 인풋을 벡터로 바꿔준다. 
# auto = encoder라고 한다.
# pretraining 을하면 비지도학습으로 언어모델이 만들어진다. fine tuning 은 추가훈련이다
# downstream task (번역, 문장분류, 질의응답) -> 추가적으로 모델에 학습을 시키는것 -> 지도학습
# Attention 이란?
# 추론하는 과정에서 어디에 초점을 맞춰야하는것이냐. 
# 가중치를 가진대상에 따라 초점을 맞춰야하는데 그것을 그 초점을 맞추는 대상이되는애를 구하는 파라미터 Q , K, V 벡터가 필요하다.
# 디코더에서 단어를 예측할때 Query 벡터와 Key 벡터를 내적을해서 가중치에 더해준다 -> 어텐션을 구하는방법. 

# why ? - 왜 마스킹을 하고 그러냐 -> 성능이 기존방식보다 좋다. 소량의 데이터로도 학습시간이 빠르다. 
# 3. Encoder-Decoder 모델 (BART, T5 - )
# pretraining , fine tuning 방식 같다.
# 트랜스포머와 구조는 동일하다. 트랜스포머는 번역을위해 사용된것이지만 , bert같은 경우엔 pretraining finetuning을 하는데  


# embedding : 벡터로 바꿔주는것 훈련 o
# enconding : 벡터로 바꿔주는것 훈련 x
# 2018년애 attention is all you need 라는 논문을 냈음, transformer라는 내용을 발표 -> NLP가 급격히 성장하였다. 
# 
# 
# RNN 

# CELL1 -> CELL2 -> CELL3 의 순차적인 구조를 가지고있다
#그러다 트랜스포머는 멀티헤드 어텐션이라는 특징을 통해 학습시간이 빠르다.

#BERT Model
#트랜스포머의 인코더 부분만 뺴서 가져온 모델 -> Attentipon 사용
# 인코더 부분을 마스크드 랭귀지 모델이라고 하는데 ...
# my [mask] is cute [sep] [mask] likes [mask]ing -> 예측
#
#인코더 모델은 할수없는데 디코더 모델은 할수있는것 . 생성이 불가능하다. 그러나 디코더모델은 생성가능하다. 그렇지만 인코더모델은 추출 가능하다.
# 



# 챗봇을 만들고싶다
#1) 인코더 모델ㅇ로 챗봇을 만들려면 .... -> 답변1,답변2,답변3 을 미리 준비해 놓는다.
#2) 디코더 모델로 챗봇을 만들려면 ....-> 사람같은 느낌을 줄수있다 but 위험할수있고 엉뚱한대답을 뱉을때가 있다.
# Out:
# 3
